# %%
# %matplotlib inline
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from linearmodels import PanelOLS

# %%
df = pd.read_csv('data.csv', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#        team         player  position                                tour  \
# 0  Infamous  Kotar? Hayama         1  Galaxy Battles II: Emerging Worlds
# 1  Infamous         Papita         2  Galaxy Battles II: Emerging Worlds
# 2  Infamous        StingeR         3  Galaxy Battles II: Emerging Worlds
# 3  Infamous       Scofield         4  Galaxy Battles II: Emerging Worlds
# 4  Infamous         Masoku         5  Galaxy Battles II: Emerging Worlds
#
#    place    prize       start         end   startelo32  startelo64  \
# 0      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
# 1      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
# 2      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
# 3      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
# 4      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
#
#         ...            endelo32     endelo64  endglickorating  endglickomu  \
# 0       ...         1114.677102  1170.334653      1646.254466   1840.23761
# 1       ...         1114.677102  1170.334653      1646.254466   1840.23761
# 2       ...         1114.677102  1170.334653      1646.254466   1840.23761
# 3       ...         1114.677102  1170.334653      1646.254466   1840.23761
# 4       ...         1114.677102  1170.334653      1646.254466   1840.23761
#
#    endglickophi  endglickosigma  endglicko2rating  endglicko2mu  \
# 0           NaN       77.593258       1596.919637   1728.907874
# 1           NaN       77.593258       1596.919637   1728.907874
# 2           NaN       77.593258       1596.919637   1728.907874
# 3           NaN       77.593258       1596.919637   1728.907874
# 4           NaN       77.593258       1596.919637   1728.907874
#
#    endglicko2phi  endglicko2sigma
# 0      52.795295              NaN
# 1      52.795295              NaN
# 2      52.795295              NaN
# 3      52.795295              NaN
# 4      52.795295              NaN
#
# [5 rows x 28 columns]

# %%
df['prize'] = df['prize'].replace('[\$,]', '', regex=True).astype(float)
df.player = df.player.replace(r'\W+', '', regex=True).str.lower()
df.start = pd.to_datetime(df.start)
df.end = pd.to_datetime(df.end)
print(df.dtypes)
df.head()
# Out:
# team                          object
# player                        object
# position                       int64
# tour                          object
# place                          int64
# prize                        float64
# start                 datetime64[ns]
# end                   datetime64[ns]
# startelo32                   float64
# startelo64                   float64
# startglickorating            float64
# startglickomu                float64
# startglickophi               float64
# startglickosigma             float64
# startglicko2rating           float64
# startglicko2mu               float64
# startglicko2phi              float64
# startglicko2sigma            float64
# endelo32                     float64
# endelo64                     float64
# endglickorating              float64
# endglickomu                  float64
# endglickophi                 float64
# endglickosigma               float64
# endglicko2rating             float64
# endglicko2mu                 float64
# endglicko2phi                float64
# endglicko2sigma              float64
# dtype: object
#        team       player  position                                tour  place  \
# 0  Infamous  kotarhayama         1  Galaxy Battles II: Emerging Worlds      7
# 1  Infamous       papita         2  Galaxy Battles II: Emerging Worlds      7
# 2  Infamous      stinger         3  Galaxy Battles II: Emerging Worlds      7
# 3  Infamous     scofield         4  Galaxy Battles II: Emerging Worlds      7
# 4  Infamous       masoku         5  Galaxy Battles II: Emerging Worlds      7
#
#      prize      start        end   startelo32  startelo64       ...         \
# 0  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
# 1  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
# 2  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
# 3  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
# 4  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
#
#       endelo32     endelo64  endglickorating  endglickomu  endglickophi  \
# 0  1114.677102  1170.334653      1646.254466   1840.23761           NaN
# 1  1114.677102  1170.334653      1646.254466   1840.23761           NaN
# 2  1114.677102  1170.334653      1646.254466   1840.23761           NaN
# 3  1114.677102  1170.334653      1646.254466   1840.23761           NaN
# 4  1114.677102  1170.334653      1646.254466   1840.23761           NaN
#
#    endglickosigma  endglicko2rating  endglicko2mu  endglicko2phi  \
# 0       77.593258       1596.919637   1728.907874      52.795295
# 1       77.593258       1596.919637   1728.907874      52.795295
# 2       77.593258       1596.919637   1728.907874      52.795295
# 3       77.593258       1596.919637   1728.907874      52.795295
# 4       77.593258       1596.919637   1728.907874      52.795295
#
#    endglicko2sigma
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 28 columns]

# %%
pool = df.groupby(['tour', 'team']).first()['prize'].groupby('tour').sum().reset_index().rename(columns={'prize': 'pool'})
pool.head()
# Out:
#                                    tour      pool
# 0            2013 WPC ACE Dota 2 League  254534.0
# 1  2015 Red Bull Battle Grounds: Dota 2   88295.0
# 2           AMD Premier League Season 1    6500.0
# 3           AMD Premier League Season 2    7000.0
# 4          AMD SAPPHIRE Dota PIT League  300000.0

# %%
df = pd.merge(df, pool, how='left', on=['tour'])

# %%
df2 = pd.read_csv('dob.csv', encoding = "ISO-8859-1")
df2.head()
# Out:
#           country       player                         name         dob
# 0          Russia         .Ark            Egor Zhabotinskii  1997-07-07
# 1         Denmark  13abyKnight                 Jon Andersen  1992-06-15
# 2          Canada         1437  Sivatheeban Sivanathapillai         NaN
# 3           China          290                    Zeng Chen         NaN
# 4  United Kingdom          2GD                James Harding  1982-12-29

# %%
df2.player = df2.player.replace(r'\W+', '', regex=True).str.lower()
df2.dob = pd.to_datetime(df2.dob)
print(df2.dtypes)
df2.head()
# Out:
# country            object
# player             object
# name               object
# dob        datetime64[ns]
# dtype: object
#           country       player                         name        dob
# 0          Russia          ark            Egor Zhabotinskii 1997-07-07
# 1         Denmark  13abyknight                 Jon Andersen 1992-06-15
# 2          Canada         1437  Sivatheeban Sivanathapillai        NaT
# 3           China          290                    Zeng Chen        NaT
# 4  United Kingdom          2gd                James Harding 1982-12-29

# %%
df = pd.merge(df, df2, how='left', on=['player'])

# %%
ra = df[['team', 'player', 'dob', 'position', 'tour', 'place', 'prize', 'pool', 'start', 'end', 'startelo64', 'endelo64']]
print(len(ra))
print(len(ra.dropna()))
ra = ra.dropna().sort_values('start').reset_index().drop('index', axis=1)
# Out:
# 9240
# 4721

# %%
ra = ra.rename(columns={'startelo64': 'srt', 'endelo64': 'ert'})
ra.head()
# Out:
#                    team      player        dob  position  \
# 0           Mousesports      kuroky 1992-10-28         5
# 1           Mousesports  sexybamboe 1992-01-20         3
# 2  Counter Logic Gaming     pajkatt 1992-09-19         1
# 3  Counter Logic Gaming      misery 1991-07-14         2
# 4  Counter Logic Gaming     lacoste 1987-11-22         3
#
#                      tour  place    prize       pool      start        end  \
# 0  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 1  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 2  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 3  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 4  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
#
#            srt         ert
# 0  1054.248131  854.326942
# 1  1054.248131  854.326942
# 2  1269.147739  957.474795
# 3  1269.147739  957.474795
# 4  1269.147739  957.474795

# %%
ra['age'] = ra.start.dt.year - ra.dob.dt.year

# %%
ra.head()
# Out:
#                    team      player        dob  position  \
# 0           Mousesports      kuroky 1992-10-28         5
# 1           Mousesports  sexybamboe 1992-01-20         3
# 2  Counter Logic Gaming     pajkatt 1992-09-19         1
# 3  Counter Logic Gaming      misery 1991-07-14         2
# 4  Counter Logic Gaming     lacoste 1987-11-22         3
#
#                      tour  place    prize       pool      start        end  \
# 0  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 1  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 2  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 3  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 4  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
#
#            srt         ert  age
# 0  1054.248131  854.326942   20
# 1  1054.248131  854.326942   20
# 2  1269.147739  957.474795   20
# 3  1269.147739  957.474795   21
# 4  1269.147739  957.474795   25

# %%
ti = ra[ra['tour'].str[:17] == 'The International'].groupby('tour').first()[['pool', 'start', 'end']]
ti
# Out:
#                               pool      start        end
# tour
# The International 2012   1775000.0 2012-08-26 2012-09-02
# The International 2013   3219309.0 2013-08-02 2013-08-11
# The International 2014  10967674.0 2014-07-08 2014-07-21
# The International 2015  17600281.0 2015-07-27 2015-08-08
# The International 2016  13916298.0 2016-08-02 2016-08-13
# The International 2017  24687919.0 2017-08-02 2017-08-12

# %%
ra['weight'] = ra['pool']
for i in range(0, 5):
    ra.loc[(ra['start'] >= ti['start'].iloc[i]) & (ra['start'] <= ti['start'].iloc[i+1]), 'weight'] = ra[(ra['start'] >= ti['start'].iloc[i]) & (ra['start'] <= ti['start'].iloc[i+1])]['pool'].apply(np.log) / np.log(ti['pool'].iloc[i])

#Only before ti7
ra = ra[ra['start'] < ti['start'].iloc[5]]

# %%
init = ra.sort_values('start').groupby('player').first()['srt'].reset_index().rename(columns={'srt': 'init'})
init.head()
# Out:
#      player         init
# 0            1006.800604
# 1        33  1013.682296
# 2       4dr   924.234998
# 3  7ckngmad  1022.550958
# 4    9pasha  1315.094989

# %%
ra = pd.merge(ra, init, how='left', on=['player'])

# %%
ra['drt'] = ra.ert - ra.srt
ra.head()
# Out:
#                    team      player        dob  position  \
# 0           Mousesports      kuroky 1992-10-28         5
# 1           Mousesports  sexybamboe 1992-01-20         3
# 2  Counter Logic Gaming     pajkatt 1992-09-19         1
# 3  Counter Logic Gaming      misery 1991-07-14         2
# 4  Counter Logic Gaming     lacoste 1987-11-22         3
#
#                      tour  place    prize       pool      start        end  \
# 0  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 1  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 2  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 3  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 4  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
#
#            srt         ert  age  weight         init         drt
# 0  1054.248131  854.326942   20     1.0  1054.248131 -199.921189
# 1  1054.248131  854.326942   20     1.0  1054.248131 -199.921189
# 2  1269.147739  957.474795   20     1.0  1269.147739 -311.672944
# 3  1269.147739  957.474795   21     1.0  1269.147739 -311.672944
# 4  1269.147739  957.474795   25     1.0  1269.147739 -311.672944

# %%
cumsums = ra[['player', 'start', 'drt']].groupby(['player', 'start']).sum().groupby(level=0).cumsum()
ra = ra.set_index(['player', 'start'])
ra['cumrt'] = cumsums
ra = ra.reset_index()
ra.head()
# Out:
#        player      start                  team        dob  position  \
# 0      kuroky 2012-08-26           Mousesports 1992-10-28         5
# 1  sexybamboe 2012-08-26           Mousesports 1992-01-20         3
# 2     pajkatt 2012-08-26  Counter Logic Gaming 1992-09-19         1
# 3      misery 2012-08-26  Counter Logic Gaming 1991-07-14         2
# 4     lacoste 2012-08-26  Counter Logic Gaming 1987-11-22         3
#
#                      tour  place    prize       pool        end          srt  \
# 0  The International 2012      7  25000.0  1775000.0 2012-09-02  1054.248131
# 1  The International 2012      7  25000.0  1775000.0 2012-09-02  1054.248131
# 2  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
# 3  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
# 4  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
#
#           ert  age  weight         init         drt       cumrt
# 0  854.326942   20     1.0  1054.248131 -199.921189 -199.921189
# 1  854.326942   20     1.0  1054.248131 -199.921189 -199.921189
# 2  957.474795   20     1.0  1269.147739 -311.672944 -311.672944
# 3  957.474795   21     1.0  1269.147739 -311.672944 -311.672944
# 4  957.474795   25     1.0  1269.147739 -311.672944 -311.672944

# %%
ra['crt'] = (ra.weight * ra.cumrt) + ra.init
ra.head()
# Out:
#        player      start                  team        dob  position  \
# 0      kuroky 2012-08-26           Mousesports 1992-10-28         5
# 1  sexybamboe 2012-08-26           Mousesports 1992-01-20         3
# 2     pajkatt 2012-08-26  Counter Logic Gaming 1992-09-19         1
# 3      misery 2012-08-26  Counter Logic Gaming 1991-07-14         2
# 4     lacoste 2012-08-26  Counter Logic Gaming 1987-11-22         3
#
#                      tour  place    prize       pool        end          srt  \
# 0  The International 2012      7  25000.0  1775000.0 2012-09-02  1054.248131
# 1  The International 2012      7  25000.0  1775000.0 2012-09-02  1054.248131
# 2  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
# 3  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
# 4  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
#
#           ert  age  weight         init         drt       cumrt         crt
# 0  854.326942   20     1.0  1054.248131 -199.921189 -199.921189  854.326942
# 1  854.326942   20     1.0  1054.248131 -199.921189 -199.921189  854.326942
# 2  957.474795   20     1.0  1269.147739 -311.672944 -311.672944  957.474795
# 3  957.474795   21     1.0  1269.147739 -311.672944 -311.672944  957.474795
# 4  957.474795   25     1.0  1269.147739 -311.672944 -311.672944  957.474795

# %%
ra = ra.drop(['srt', 'ert', 'init', 'drt', 'cumrt'], axis=1)
ra.tail()
# Out:
#           player      start           team        dob  position  \
# 4249      kuroky 2017-07-21    Team Liquid 1992-10-28         5
# 4250  alohadance 2017-07-21  Vega Squadron 1997-09-15         1
# 4251           g 2017-07-21  Vega Squadron 1992-04-16         2
# 4252   afterlife 2017-07-21  Vega Squadron 1997-03-13         3
# 4253  matumbaman 2017-07-21    Team Liquid 1995-03-03         1
#
#                       tour  place    prize      pool        end  age  \
# 4249  DreamLeague Season 7      1  80000.0  175000.0 2017-07-22   25
# 4250  DreamLeague Season 7      4  20000.0  175000.0 2017-07-22   20
# 4251  DreamLeague Season 7      4  20000.0  175000.0 2017-07-22   25
# 4252  DreamLeague Season 7      4  20000.0  175000.0 2017-07-22   20
# 4253  DreamLeague Season 7      1  80000.0  175000.0 2017-07-22   22
#
#         weight          crt
# 4249  0.733957  1258.398246
# 4250  0.733957  1281.273997
# 4251  0.733957  1098.113645
# 4252  0.733957  1084.259969
# 4253  0.733957  1452.481802

# %%
ra[['player', 'team', 'crt', 'end']].groupby('player').last().sort_values('crt', ascending=False)
# Out:
#                                 team          crt        end
# player
# ppd                    Evil Geniuses  2628.106510 2016-08-13
# n0tail                            OG  2335.269642 2017-07-09
# yao                       LGD Gaming  2333.073036 2017-07-09
# fly                               OG  2232.388384 2017-07-09
# ddc                LGD.Forever Young  2124.933902 2017-07-09
# faith                         Newbee  2103.125714 2017-07-09
# era                         Alliance  2002.580164 2017-07-09
# sumail                 Evil Geniuses  1974.943804 2017-05-28
# yyf                  Invictus Gaming  1970.070955 2014-07-21
# xiao8              LGD.Forever Young  1910.182334 2016-12-10
# bone7                 Prodota Gaming  1894.929334 2016-12-16
# zai                    Evil Geniuses  1858.084708 2017-07-09
# universe               Evil Geniuses  1836.992347 2017-07-09
# eternalenvy                  Team NP  1825.895529 2017-06-18
# miracle                  Team Liquid  1775.121254 2017-07-22
# burning              Invictus Gaming  1772.738256 2017-07-09
# lanm                           EHOME  1723.387082 2016-12-10
# yoky                      Virtus.pro  1716.262360 2016-06-19
# trixi                  Escape Gaming  1708.715066 2016-11-26
# lightofheaven             Virtus.pro  1678.920797 2013-12-12
# arteezy                Evil Geniuses  1658.881552 2017-07-09
# luo                     CDEC Avenger  1634.406599 2016-07-17
# mason                  Digital Chaos  1554.903006 2017-06-18
# puppey                   Team Secret  1511.422281 2017-07-22
# monet              LGD.Forever Young  1491.844666 2017-07-09
# chuan                    Vici Gaming  1481.835711 2017-06-18
# boboka               Invictus Gaming  1478.327335 2017-07-09
# xxs                  Invictus Gaming  1478.327335 2017-07-09
# jixing             LGD.Forever Young  1477.200877 2017-04-04
# arsart                    Virtus.pro  1465.518809 2014-06-25
# ...                              ...          ...        ...
# 7ckngmad                    Alliance   767.514041 2015-06-21
# sylar                          EHOME   767.431690 2016-12-10
# sexybamboe            Prodota Gaming   765.424275 2016-12-16
# blowyourbrain             Virtus.pro   758.699851 2014-01-19
# sonneiko               Natus Vincere   738.057860 2017-06-18
# artstyle               Natus Vincere   727.087988 2016-08-13
# nana            WarriorsGaming.Unity   724.813953 2017-06-03
# demon              CompLexity Gaming   710.926822 2017-05-31
# vigoss                   Moscow Five   694.678515 2014-12-19
# illidan               Fantastic Five   685.688902 2016-09-01
# fenrir                      Team VGJ   677.599779 2017-06-18
# handsken                    Alliance   665.642887 2017-07-09
# limmp                       Alliance   665.642887 2017-07-09
# pajkatt                Natus Vincere   665.457231 2017-06-18
# garder                         EHOME   660.718503 2016-12-10
# moo                CompLexity Gaming   657.708602 2017-05-31
# agressif                    Team VGJ   635.560299 2017-06-18
# fng                      Team Spirit   634.387837 2017-07-09
# dendi                  Natus Vincere   622.051329 2017-06-18
# fy                       Vici Gaming   589.213978 2017-07-09
# ohaiyo                        Fnatic   585.880234 2017-06-03
# chessie            CompLexity Gaming   536.317092 2016-07-24
# egm                         Alliance   474.465527 2017-05-21
# fluffnstuff              Team Archon   453.490112 2016-03-06
# s4                                OG   447.860068 2017-07-09
# goblak                   Team Spirit   440.872772 2016-05-01
# jeyo                       HappyFeet   193.542037 2017-06-18
# akke                        Alliance   -23.399644 2016-07-26
# admiralbulldog              Alliance   -86.621184 2016-09-01
# loda                        Alliance   -96.433101 2017-05-21
#
# [270 rows x 3 columns]

# %%
ra[ra['player'] == 'ppd'][['start', 'crt']].set_index('start').plot()

# %%
ra.head()
# Out:
#        player      start                  team        dob  position  \
# 0      kuroky 2012-08-26           Mousesports 1992-10-28         5
# 1  sexybamboe 2012-08-26           Mousesports 1992-01-20         3
# 2     pajkatt 2012-08-26  Counter Logic Gaming 1992-09-19         1
# 3      misery 2012-08-26  Counter Logic Gaming 1991-07-14         2
# 4     lacoste 2012-08-26  Counter Logic Gaming 1987-11-22         3
#
#                      tour  place    prize       pool        end  age  weight  \
# 0  The International 2012      7  25000.0  1775000.0 2012-09-02   20     1.0
# 1  The International 2012      7  25000.0  1775000.0 2012-09-02   20     1.0
# 2  The International 2012      7  25000.0  1775000.0 2012-09-02   20     1.0
# 3  The International 2012      7  25000.0  1775000.0 2012-09-02   21     1.0
# 4  The International 2012      7  25000.0  1775000.0 2012-09-02   25     1.0
#
#           crt
# 0  854.326942
# 1  854.326942
# 2  957.474795
# 3  957.474795
# 4  957.474795

# %%
ra = ra[ra['player'] != '']
ra = ra[(ra['age'] > 18) & (ra['age'] < 28)]

# %%
#age frequency
ra.groupby('age').size().plot(kind='bar')

# %%
#analysis
ra = ra.set_index(['player', 'tour']).sort_index()
ra['agesq'] = ra.age * ra.age

# %%
y = ra.groupby('age').mean()['crt'].reset_index()['crt']
x = ra.groupby('age').mean()['crt'].reset_index()['age']
plt.plot(x, y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 3))(np.unique(x)), 'r')

# %%
y = ra['crt']
x = ra['age']
plt.scatter(x, y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 2))(np.unique(x)), 'r')

# %%
#core vs sup
cor = ra[ra['position'] <= 3]
sup = ra[ra['position'] > 3]
cor.head()
# Out:
#                                              start            team        dob  \
# player tour
# 33     Mr. Cat Invitational Europe      2017-05-02  Prodota Gaming 1997-04-17
#        World Cyber Arena 2016           2016-12-14  Prodota Gaming 1997-04-17
# 4dr    Dota 2 Canada Cup Season 6       2015-11-28     PaiN Gaming 1993-07-13
#        DreamLeague Season 7 NA Division 2017-05-30     SG e-sports 1993-07-13
#        The Final Match Season 1         2017-07-07     SG e-sports 1993-07-13
#
#                                          position  place    prize      pool  \
# player tour
# 33     Mr. Cat Invitational Europe              3      4   5000.0   70000.0
#        World Cyber Arena 2016                   2      4  28744.0  732972.0
# 4dr    Dota 2 Canada Cup Season 6               1      3   4076.0   93751.0
#        DreamLeague Season 7 NA Division         2      4   1000.0   12000.0
#        The Final Match Season 1                 2      2  11250.0   50000.0
#
#                                                end  age    weight  \
# player tour
# 33     Mr. Cat Invitational Europe      2017-05-18   20  0.678250
#        World Cyber Arena 2016           2016-12-16   19  0.821036
# 4dr    Dota 2 Canada Cup Season 6       2016-02-08   22  0.686214
#        DreamLeague Season 7 NA Division 2017-05-31   24  0.571032
#        The Final Match Season 1         2017-07-09   24  0.657794
#
#                                                  crt  agesq
# player tour
# 33     Mr. Cat Invitational Europe       1026.367702    400
#        World Cyber Arena 2016             999.974471    361
# 4dr    Dota 2 Canada Cup Season 6         900.438705    484
#        DreamLeague Season 7 NA Division   931.489252    576
#        The Final Match Season 1           932.204816    576

# %%
cor.groupby('age').size().plot(kind='bar')

# %%
sup.groupby('age').size().plot(kind='bar')

# %%
y = cor['crt']
x = cor['age']
plt.scatter(x, y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), 'r')

# %%
y = sup['crt']
x = sup['age']
plt.scatter(x, y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 2))(np.unique(x)), 'r')
