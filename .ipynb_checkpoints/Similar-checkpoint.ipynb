# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
import yaml

# %%
alltour = 'http://liquipedia.net/dota2/Premier_Tournaments'
htmlall = requests.get(alltour)
htmlall.encoding = 'utf-8'
soup = BeautifulSoup(htmlall.text, "lxml")
divs = soup.find_all('b')
urls = []
for div in divs:
    urls.append(re.search(r'href="(.+?)"', str(div))[1])
df = pd.DataFrame(columns = ['team', 'player', 'bday', 'tour', 'start', 'end', 'startelo32', 'startelo64', 'endelo32', 'endelo64'])
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
for url in urls[10:15]:
    url = 'http://wiki.teamliquid.net' + url
    html = requests.get(url)
    html.encoding = 'utf-8'
    soup = BeautifulSoup(html.text, "lxml")
    divs = soup.find_all('div', class_="teamcard")
    tournamentname = soup.find_all('span', dir="auto")
    tournamentname = tournamentname[0].contents[0]
    info = soup.find_all('div', text = re.compile(r'\d*-\d*-\d*'), class_="infobox-cell-2")
    startdate = info[0].contents[0]
    enddate = info[1].contents[0]
    startdate2 = startdate[-2:] + startdate[4:8] + startdate[:4]
    enddate2 = enddate[-2:] + enddate[4:8] + enddate[:4]
    urldat = 'http://www.datdota.com/api/ratings?date=' + startdate2
    htmldat = requests.get(urldat)
    htmldat.encoding = 'utf-8'
    elo = BeautifulSoup(htmldat.text, "lxml")
    elodict = yaml.load(elo.text)
    startelolist = elodict['data']
    
    urldat = 'http://www.datdota.com/api/ratings?date=' + enddate2
    htmldat = requests.get(urldat)
    htmldat.encoding = 'utf-8'
    elo = BeautifulSoup(htmldat.text, "lxml")
    elodict = yaml.load(elo.text)
    endelolist = elodict['data']
    for div in divs:
        center = div.find('center')
        teamname = re.search(r'title="(.+?)"', str(center))[1]
        startelo32 = 'N/A'
        startelo64 = 'N/A'
        endelo32 = 'N/A'
        endelo64 = 'N/A'
        for startelo in startelolist:
            if startelo['teamName'].lower() == teamname.lower():
                startelo32 = startelo['elo32']['current']
                startelo64 = startelo['elo64']['current']
        for endelo in endelolist:
            if endelo['teamName'].lower() == teamname.lower():
                endelo32 = endelo['elo32']['current']
                endelo64 = endelo['elo64']['current']
        for table in div.find_all('table', class_="table table-bordered list"):
            for tr in table.find_all('tr'):
                string = re.search(r'<th>([12345])</th><td><a.+</a>.+<a href="(.+)" title="(.+?)"', str(tr))
                if string is None:
                    continue
                url2 = 'http://wiki.teamliquid.net' + string[2]
                html2 = requests.get(url2)
                html2.encoding = 'utf-8'
                bd = BeautifulSoup(html2.text, "lxml").find('span', class_='bday')   
                if bd is not None:
                    bday = "".join([str(x) for x in bd.contents])
                else:
                    bday = 'N/A'
                df = df.append({'team': teamname, 
                                'player': string[3], 
                                'bday': bday, 
                                'tour': tournamentname, 
                                'start': startdate, 
                                'end': enddate, 
                                'startelo32': startelo32, 
                                'startelo64': startelo64, 
                                'endelo32': endelo32, 
                                'endelo64': endelo64}, ignore_index=True)

# %%
df
# Out:
#                 team           player        bday                tour  \
# 0             Newbee            Moogy  1994-04-19      Galaxy Battles
# 1             Newbee             Sccc  1995-08-18      Galaxy Battles
# 2             Newbee             Kpii         N/A      Galaxy Battles
# 3             Newbee             Kaka  1992-11-07      Galaxy Battles
# 4             Newbee            Faith  1992-02-06      Galaxy Battles
# 5        IG Vitality        Paparazi灬  1996-06-27      Galaxy Battles
# 193  2017-05-25  2017-05-28        N/A        N/A      N/A      N/A
# 194  2017-05-25  2017-05-28        N/A        N/A      N/A      N/A
# 195  2017-05-25  2017-05-28        N/A        N/A      N/A      N/A
# 196  2017-05-25  2017-05-28        N/A        N/A      N/A      N/A
# 197  2017-05-25  2017-05-28    1150.18    1150.18  1106.62  1106.62
# 198  2017-05-25  2017-05-28    1150.18    1150.18  1106.62  1106.62
# 199  2017-05-25  2017-05-28    1150.18    1150.18  1106.62  1106.62
# 200  2017-05-25  2017-05-28    1150.18    1150.18  1106.62  1106.62
# 201  2017-05-25  2017-05-28    1150.18    1150.18  1106.62  1106.62
#
# [202 rows x 10 columns]

# %%
df[df['startelo32'] == 'N/A']
# Out:
#                                   team               player        bday  \
# 5                          IG Vitality            Paparazi灬  1996-06-27
# 6                          IG Vitality               InJuly  1993-01-28
# 7                          IG Vitality      Super (Su Peng)  1989-10-19
# 8                          IG Vitality            Dogf1ghts  1995-12-05
# 14                          Planet Odd           Resolut1on  1996-09-02
# 15                          Planet Odd                  W33  1995-03-06
# 16                          Planet Odd          MoonMeander  1992-01-28
# 17                          Planet Odd               MiSeRy  1991-07-14
# 18                          Planet Odd                Saksa  1995-06-12
# 24                            Infamous               Benjaz  1993-09-30
# 25                            Infamous               Timado  2000-09-06
# 26                            Infamous             Kingteka  1997-02-07
# 27                            Infamous              Matthew         N/A
# 28                            Infamous                Accel  1995-10-20
# 34                           HappyFeet                 Jeyo  1993-04-19
# 35                           HappyFeet               Benhur  1997-03-05
# 36                           HappyFeet                  Yaj  1998-03-22
# 37                           HappyFeet                 Julz  1992-12-21
# 38                           HappyFeet           JessieVash  1990-02-21
# 57                          LGD Gaming                  Ame  1997-04-07
# 58                          LGD Gaming                Maybe  1995-12-16
# 59                          LGD Gaming                  Yao  1990-12-23
# 60                          LGD Gaming             Victoria  1995-11-05
# 103                         Planet Odd           Resolut1on  1996-09-02
# 104                         Planet Odd                  W33  1995-03-06
# 105                         Planet Odd          MoonMeander  1992-01-28
# 106                         Planet Odd               MiSeRy  1991-07-14
# 107                         Planet Odd                Saksa  1995-06-12
# 123  Filler Pick (page does not exist)              Merlini  1987-10-23
# 124  Filler Pick (page does not exist)                 GoDz  1990-02-27
# 125  Filler Pick (page does not exist)               WinteR  1989-08-21
# 126  Filler Pick (page does not exist)               Fogged  1989-12-12
# 127  Filler Pick (page does not exist)  Purge (Kevin Godec)  1987-08-17
# 128          KBU (page does not exist)                   NS  1988-09-24
# 129          KBU (page does not exist)                XBOCT  1990-12-29
# 130          KBU (page does not exist)                Dread  1991-01-19
# 131          KBU (page does not exist)               Inmate  1991-11-12
# 142                   Team Singularity          Exotic Deer         N/A
# 143                   Team Singularity                Nisha  2000-09-28
# 144                   Team Singularity                Patos         N/A
# 145                   Team Singularity            EL lisasH  1996-07-28
# 146                   Team Singularity                Kacor         N/A
# 161                        IG Vitality                 KYxY  1991-05-26
# 162                        IG Vitality               InJuly  1993-01-28
# 163                        IG Vitality      Super (Su Peng)  1989-10-19
# 164                        IG Vitality            Dogf1ghts  1995-12-05
# 192                      Team Faceless                  Xy-  1991-12-27
# 193                      Team Faceless               Black^  1993-05-27
# 194                      Team Faceless            Iceiceice  1990-06-17
# 195                      Team Faceless                 Jabz  1998-09-22
# 196                      Team Faceless                 NutZ  1989-08-31
#
#                    tour       start         end startelo32 startelo64  \
# 5        Galaxy Battles  2017-06-15  2017-06-18        N/A        N/A
#