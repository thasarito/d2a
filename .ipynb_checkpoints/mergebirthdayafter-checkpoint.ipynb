# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
import yaml

# %%
alltour = 'http://liquipedia.net/dota2/Major_Tournaments'
htmlall = requests.get(alltour)
htmlall.encoding = 'utf-8'
soup = BeautifulSoup(htmlall.text, "lxml")
divs = soup.find_all('b')
urls = []
for div in divs:
    urls.append(re.search(r'href="(.+?)"', str(div))[1])
df = pd.DataFrame(columns = ['team', 'player', 'bday', 'tour', 'start', 'end', 'startelo32', 'startelo64', 'endelo32', 'endelo64'])
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
urls
# Out:
# ['/dota2/Dota_Major_Championships',
#  '/dota2/GESC/Season_1/Bangkok',
#  '/dota2/DreamLeague/Season_9',
#  '/dota2/GESC/Season_1/Jakarta',
#  '/dota2/StarLadder/i-League_Invitational/4',
#  '/dota2/ESL_One/Genting/2018',
#  '/dota2/Captains_Draft/4',
#  '/dota2/The_Summit/8',
#  '/dota2/ROG_MASTERS/2017',
#  '/dota2/Mars_Dota_2_League/Macau/2017',
#  '/dota2/Perfect_World_Masters/2017',
#  '/dota2/China_Top/2017',
#  '/dota2/Adrenaline_Cyber_League/2017',
#  '/dota2/Dota2_Professional_League/Season_4/Top',
#  '/dota2/Dota_Pit_League/Season_6',
#  '/dota2/PGL_Open/Bucharest/2017',
#  '/dota2/StarLadder/i-League_Invitational/3',
#  '/dota2/DreamLeague/Season_7',
#  '/dota2/The_Final_Match/Season_1',
#  '/dota2/DreamLeague/Season_7/NA_Division',
#  '/dota2/Russian_e-Sports_Cup/2017',
#  '/dota2/DreamLeague/Season_7/EU_Division',
#  '/dota2/Mr._Cat_Invitational/Europe',
#  '/dota2/Dota2_Professional_League/Season_3/Top',
#  '/dota2/Elimination_Mode/3',
#  '/dota2/Russian_e-Sports_Cup/2016',
#  '/dota2/Dota2_Professional_League/Season_2/Top',
#  '/dota2/Dota2_ACE/Provisional',
#  '/dota2/China_Top/2016',
#  '/dota2/Dota2_Professional_League/Season_2/Secondary',
#  '/dota2/DreamLeague/Season_6',
#  '/dota2/World_Electronic_Sports_Games/2016/Asia_Pacific',
#  '/dota2/ROG_MASTERS/2016',
#  '/dota2/World_Cyber_Arena/2016/America_Qualifier',
#  '/dota2/World_Cyber_Arena/2016/Chinese_Qualifiers/S3',
#  '/dota2/DreamLeague/Season_6/League_Play',
#  '/dota2/World_Electronic_Sports_Games/2016/Americas',
#  '/dota2/FACEIT/Invitational/1',
#  '/dota2/Nanyang_Dota_2_Championships/Cruise_Cup/1',
#  '/dota2/World_Electronic_Sports_Games/2016/Europe_CIS',
#  '/dota2/Shanghai_Dota_2_Open/2',
#  '/dota2/World_Cyber_Arena/2016/Chinese_Qualifiers/S2',
#  '/dota2/Red_Bull_Heroicks',
#  '/dota2/MPGL/Southeast_Asian_Championship',
#  '/dota2/World_Cyber_Arena/2016/Europe_Main_Qualifier',
#  '/dota2/World_Electronic_Sports_Games/2016/Middle_East_and_Africa',
#  '/dota2/VPGame_Pro_League/Season_2',
#  '/dota2/Global_Grand_Masters',
#  '/dota2/Pro_Gamer_League/2016/Summer',
#  '/dota2/Dota2_Professional_League/Season_1',
#  '/dota2/G-League_2016',
#  '/dota2/National_Electronic_Arena/2016',
#  '/dota2/DreamLeague/Season_5',
#  '/dota2/World_Cyber_Arena/2016/SEA_Qualifiers/S1',
#  '/dota2/World_Cyber_Arena/2016/Chinese_Qualifiers/S1',
#  '/dota2/Captains_Draft/3',
#  '/dota2/Dota_2_Canada_Cup/Season_6',
#  '/dota2/Shanghai_Dota_2_Open/1',
#  '/dota2/ECL/2015/Autumn',
#  '/dota2/Dota_2_Radiant_%26_Dire_Cup/2015',
#  '/dota2/Dota_2_Champions_League/Christmas_Charity_Magic',
#  '/dota2/The_Defense/Season_5',
#  '/dota2/DreamLeague/Season_4',
#  '/dota2/PGL_Dota_2_Pro-AM',
#  '/dota2/Dota2_Battle_Arena',
#  '/dota2/Dota_2_Champions_League/Season_6',
#  '/dota2/World_Cyber_Arena/2015/SEA_Qualifiers',
#  '/dota2/World_Cyber_Arena/2015/European_Qualifiers',
#  '/dota2/Gaming_Paradise_2015',
#  '/dota2/G-League_2015',
#  '/dota2/World_Cyber_Arena/2015/Chinese_Qualifiers',
#  '/dota2/ECL/2015/Spring',
#  '/dota2/World_Cyber_Arena/2015/American_Qualifiers',
#  '/dota2/MarsTV_Dota_2_League/2015/Chinese_League',
#  '/dota2/MPGL/Season_7/SEA',
#  '/dota2/2015_Red_Bull_Battle_Grounds:_Dota_2',
#  '/dota2/RoG_Play_It_Cool_Dota_2_Invitational',
#  '/dota2/VPGame_Pro_League/Season_1',
#  '/dota2/Major_All_Stars_Dota_2_Tournament',
#  '/dota2/ECL_2014/Autumn',
#  '/dota2/OK.-_Dota_2_Cup',
#  '/dota2/G-League_2014',
#  '/dota2/Korea_Dota_2_League/Season_4',
#  '/dota2/Battle_of_Central_Europe/Season_3',
#  '/dota2/Esportal_Dota_2_League/Invitational_Tournament_1',
#  '/dota2/National_Electronic_Sports_Open_2014',
#  '/dota2/IeSF_2014_World_Championship',
#  '/dota2/MSI_Beat_IT_2014',
#  '/dota2/Synergy_League_Season_1',
#  '/dota2/Brasil_Game_Cup/2014',
#  '/dota2/Korea_Dota_2_League/Season_3',
#  '/dota2/Sina_Cup_Supernova_Dota_2_Open/Season_5',
#  '/dota2/NVIDIA_Game_24',
#  '/dota2/IeSF_Asian_Championships',
#  '/dota2/Game_Show_League/Season_1',
#  '/dota2/Megafon_Battle_Arena',
#  '/dota2/Korea_Dota_2_League/Season_2',
#  '/dota2/V_Games_Tournament',
#  '/dota2/WVW_National_Electronic_Sports_Classic/June',
#  '/dota2/GEST_The_Challenge_June',
#  '/dota2/CDEC_New_Star_Challenge',
#  '/dota2/Korea_Dota_2_League/Season_2/Tier_1',
#  '/dota2/ECL_2014/Season_1',
#  '/dota2/American_Dota_League/Season_2',
#  '/dota2/Techlabs_Cup/2014/Season_2',
#  '/dota2/WVW_National_Electronic_Sports_Classic/April',
#  '/dota2/DreamHack/2014/Bucharest',
#  '/dota2/Fragbite_Masters_2014',
#  '/dota2/MLG_T.K.O._Tournament/Europe',
#  '/dota2/Korea_Dota_2_League/Season_1',
#  '/dota2/Techlabs_Cup/2014/Season_1',
#  '/dota2/MLG_T.K.O._Tournament/America',
#  '/dota2/Captains_Draft/1',
#  '/dota2/Netolic_Pro_League_5/East',
#  '/dota2/Korea_Dota_2_League/Season_1/Tier_1',
#  '/dota2/Monster_Energy_Invitational',
#  '/dota2/Sina_Cup_Supernova_Dota_2_Open/Season_3',
#  '/dota2/Electronic_Sports_Prime/Shock_Therapy_Cup',
#  '/dota2/Pinnacle_Pro-Am_Cup',
#  '/dota2/Asian_Cyber_Games_2013',
#  '/dota2/Fengyun_Dota_2_Tournament',
#  '/dota2/Fragbite_Masters_2013',
#  '/dota2/Netolic_Pro_League_4/West',
#  '/dota2/Rapture_Gaming_Network_League_2013/2014',
#  '/dota2/Sina_Cup_Supernova_Dota_2_Open/Season_2',
#  '/dota2/MLG/2013/Fall_Season/Invitational',
#  '/dota2/Techlabs_Cup/2013/Season_3',
#  '/dota2/Sina_Cup_Supernova_Dota_2_Open/Season_1',
#  '/dota2/Techlabs_Cup/2013/Season_2',
#  '/dota2/Corsair_Gaming_Summer_Dota_2_Tournament_2013',
#  '/dota2/AMD_Premier_League/Season_2',
#  '/dota2/Nexon_Starter_League',
#  '/dota2/American_Dota_League/Season_1',
#  '/dota2/E2MAX_L33t_Championship',
#  '/dota2/Curse_Dota_2_Invitational',
#  '/dota2/AMD_Premier_League/Season_1',
#  '/dota2/WePlay_Dota2_League/Season_1',
#  '/dota2/DreamHack/2013/Invitational',
#  '/dota2/Ritmix_Russian_DOTA_2_League',
#  '/dota2/Techlabs_Cup/2013/Season_1',
#  '/dota2/Armaggeddon_Dota_2_Grand_Slam_Asia_2013',
#  '/dota2/GosuLeague_Season_5_Division_1',
#  '/dota2/GosuLeague_Season_5',
#  '/dota2/GosuLeague_Season_4',
#  '/dota2/GosuLeague_Season_4_Division_1',
#  '/dota2/Alienware_2012_Battlegrounds',
#  '/dota2/WCG_Asia_2012',
#  '/dota2/Samsung_European_Encounter',
#  '/dota2/ProDOTA2_League/Season_1/Non_Pro',
#  '/dota2/GosuLeague_Season_3',
#  '/dota2/GosuLeague_Season_2',
#  '/dota2/Gigabyte_Dota_2_Masters',
#  '/dota2/GosuLeague_Season_1',
#  '/dota2/Dota2Replays_Brawl',
#  '/dota2/Razer_Dota_2_Tournament',
#  '/dota2/Malaysia_Invitational',
#  '/dota2/DreamHack/2011/Winter']

# %%
for url in urls[5:10]:
    url = 'http://wiki.teamliquid.net' + url
    html = requests.get(url)
    html.encoding = 'utf-8'
    soup = BeautifulSoup(html.text, "lxml")
    divs = soup.find_all('div', class_="teamcard")
    tournamentname = soup.find_all('span', dir="auto")
    tournamentname = tournamentname[0].contents[0]
    info = soup.find_all('div', text = re.compile(r'\d*-\d*-\d*'), class_="infobox-cell-2")
    startdate = info[0].contents[0]
    enddate = info[1].contents[0]
    startdate2 = startdate[-2:] + startdate[4:8] + startdate[:4]
    enddate2 = enddate[-2:] + enddate[4:8] + enddate[:4]
    urldat = 'http://www.datdota.com/api/ratings?date=' + startdate2
    htmldat = requests.get(urldat)
    htmldat.encoding = 'utf-8'
    elo = BeautifulSoup(htmldat.text, "lxml")
    elodict = yaml.load(elo.text)
    startelolist = elodict['data']    
    urldat = 'http://www.datdota.com/api/ratings?date=' + enddate2
    htmldat = requests.get(urldat)
    htmldat.encoding = 'utf-8'
    elo = BeautifulSoup(htmldat.text, "lxml")
    elodict = yaml.load(elo.text)
    endelolist = elodict['data']
    for div in divs:
        center = div.find('center')
        teamname = re.search(r'title="(.+?)"', str(center))[1]
        startelo32 = 'N/A'
        startelo64 = 'N/A'
        endelo32 = 'N/A'
        endelo64 = 'N/A'
        for startelo in startelolist:
            if similar(startelo['teamName'].lower(), teamname.lower()) > 0.5:
                startelo32 = startelo['elo32']['current']
                startelo64 = startelo['elo64']['current']
        for endelo in endelolist:
            if similar(endelo['teamName'].lower(), teamname.lower()) > 0.5:
                endelo32 = endelo['elo32']['current']
                endelo64 = endelo['elo64']['current']
        for table in div.find_all('table', class_="table table-bordered list"):
            for tr in table.find_all('tr'):
                string = re.search(r'<th>([12345])</th><td><a.+</a>.+<a href="(.+)" title="(.+?)"', str(tr))
                if string is None:
                    continue
                url2 = 'http://wiki.teamliquid.net' + string[2]
                html2 = requests.get(url2)
                html2.encoding = 'utf-8'
                bd = BeautifulSoup(html2.text, "lxml").find('span', class_='bday')   
                if bd is not None:
                    bday = "".join([str(x) for x in bd.contents])
                else:
                    bday = 'N/A'
                df = df.append({'team': teamname, 
                                'player': string[3], 
                                'bday': bday, 
                                'tour': tournamentname, 
                                'start': startdate, 
                                'end': enddate, 
                                'startelo32': startelo32, 
                                'startelo64': startelo64, 
                                'endelo32': endelo32, 
                                'endelo64': endelo64}, ignore_index=True)

# %%
df.to_csv('ter.csv')

# %%
df
# Out:
#                   team         player        bday                  tour  \
# 0           Virtus.pro      RAMZES666  1999-04-25  ESL One Genting 2018
# 1           Virtus.pro          Noone  1997-09-04  ESL One Genting 2018
# 2           Virtus.pro         9pasha  1992-06-30  ESL One Genting 2018
# 3           Virtus.pro            Lil  1995-12-24  ESL One Genting 2018
# 4           Virtus.pro           Solo  1990-08-07  ESL One Genting 2018
# 5          Team Liquid     MATUMBAMAN  1995-03-03  ESL One Genting 2018
# 6          Team Liquid       Miracle-  1997-06-20  ESL One Genting 2018
# 7          Team Liquid   MinD ContRoL  1995-01-20  ESL One Genting 2018
# 8          Team Liquid             GH         N/A  ESL One Genting 2018
# 9          Team Liquid         KuroKy  1992-10-28  ESL One Genting 2018
# 10              Newbee          Moogy  1994-04-19  ESL One Genting 2018
# 11              Newbee           Sccc  1995-08-18  ESL One Genting 2018
# 12              Newbee           Kpii         N/A  ESL One Genting 2018
# 13              Newbee           Kaka  1992-11-07  ESL One Genting 2018
# 14              Newbee          Faith  1992-02-06  ESL One Genting 2018
# 15             Mineski           NaNa  1995-02-12  ESL One Genting 2018
# 16             Mineski          Mushi  1990-11-27  ESL One Genting 2018
# 17             Mineski      Iceiceice  1990-06-17  ESL One Genting 2018
# 18             Mineski           Jabz  1998-09-22  ESL One Genting 2018
# 19             Mineski    Ninjaboogie  1992-01-31  ESL One Genting 2018
# 20       Evil Geniuses        Arteezy  1996-07-01  ESL One Genting 2018
# 21       Evil Geniuses           Fear  1988-02-19  ESL One Genting 2018
# 22       Evil Geniuses          Cr1t-  1996-07-13  ESL One Genting 2018
# 23       Evil Geniuses         MiSeRy  1991-07-14  ESL One Genting 2018
# 24         Team Secret            Ace  1994-01-19  ESL One Genting 2018
# 25         Team Secret           Fata  1993-02-24  ESL One Genting 2018
# 26         Team Secret         Puppey  1990-03-06  ESL One Genting 2018
# 27         Vici Gaming      Paparazi灬  1996-06-27  ESL One Genting 2018
# 28         Vici Gaming            Ori         N/A  ESL One Genting 2018
# 29         Vici Gaming         ELeVeN  1995-12-07  ESL One Genting 2018
