# %%
# %matplotlib inline
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# machine learning
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from linearmodels import PanelOLS

# %%
df = pd.read_csv('data.csv', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#        team         player  position                                tour  \
# 0  Infamous  Kotar? Hayama         1  Galaxy Battles II: Emerging Worlds
# 1  Infamous         Papita         2  Galaxy Battles II: Emerging Worlds
# 2  Infamous        StingeR         3  Galaxy Battles II: Emerging Worlds
# 3  Infamous       Scofield         4  Galaxy Battles II: Emerging Worlds
# 4  Infamous         Masoku         5  Galaxy Battles II: Emerging Worlds
#
#    place    prize       start         end   startelo32  startelo64  \
# 0      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
# 1      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
# 2      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
# 3      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
# 4      7  $20,000  2018-01-19  2018-01-21  1116.266143  1172.69492
#
#         ...            endelo32     endelo64  endglickorating  endglickomu  \
# 0       ...         1114.677102  1170.334653      1646.254466   1840.23761
# 1       ...         1114.677102  1170.334653      1646.254466   1840.23761
# 2       ...         1114.677102  1170.334653      1646.254466   1840.23761
# 3       ...         1114.677102  1170.334653      1646.254466   1840.23761
# 4       ...         1114.677102  1170.334653      1646.254466   1840.23761
#
#    endglickophi  endglickosigma  endglicko2rating  endglicko2mu  \
# 0           NaN       77.593258       1596.919637   1728.907874
# 1           NaN       77.593258       1596.919637   1728.907874
# 2           NaN       77.593258       1596.919637   1728.907874
# 3           NaN       77.593258       1596.919637   1728.907874
# 4           NaN       77.593258       1596.919637   1728.907874
#
#    endglicko2phi  endglicko2sigma
# 0      52.795295              NaN
# 1      52.795295              NaN
# 2      52.795295              NaN
# 3      52.795295              NaN
# 4      52.795295              NaN
#
# [5 rows x 28 columns]

# %%
df['prize'] = df['prize'].replace('[\$,]', '', regex=True).astype(float)
df.player = df.player.replace(r'\W+', '', regex=True).str.lower()
df.start = pd.to_datetime(df.start)
df.end = pd.to_datetime(df.end)
print(df.dtypes)
df.head()
# Out:
# team                          object
# player                        object
# position                       int64
# tour                          object
# place                          int64
# prize                        float64
# start                 datetime64[ns]
# end                   datetime64[ns]
# startelo32                   float64
# startelo64                   float64
# startglickorating            float64
# startglickomu                float64
# startglickophi               float64
# startglickosigma             float64
# startglicko2rating           float64
# startglicko2mu               float64
# startglicko2phi              float64
# startglicko2sigma            float64
# endelo32                     float64
# endelo64                     float64
# endglickorating              float64
# endglickomu                  float64
# endglickophi                 float64
# endglickosigma               float64
# endglicko2rating             float64
# endglicko2mu                 float64
# endglicko2phi                float64
# endglicko2sigma              float64
# dtype: object
#        team       player  position                                tour  place  \
# 0  Infamous  kotarhayama         1  Galaxy Battles II: Emerging Worlds      7
# 1  Infamous       papita         2  Galaxy Battles II: Emerging Worlds      7
# 2  Infamous      stinger         3  Galaxy Battles II: Emerging Worlds      7
# 3  Infamous     scofield         4  Galaxy Battles II: Emerging Worlds      7
# 4  Infamous       masoku         5  Galaxy Battles II: Emerging Worlds      7
#
#      prize      start        end   startelo32  startelo64       ...         \
# 0  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
# 1  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
# 2  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
# 3  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
# 4  20000.0 2018-01-19 2018-01-21  1116.266143  1172.69492       ...
#
#       endelo32     endelo64  endglickorating  endglickomu  endglickophi  \
# 0  1114.677102  1170.334653      1646.254466   1840.23761           NaN
# 1  1114.677102  1170.334653      1646.254466   1840.23761           NaN
# 2  1114.677102  1170.334653      1646.254466   1840.23761           NaN
# 3  1114.677102  1170.334653      1646.254466   1840.23761           NaN
# 4  1114.677102  1170.334653      1646.254466   1840.23761           NaN
#
#    endglickosigma  endglicko2rating  endglicko2mu  endglicko2phi  \
# 0       77.593258       1596.919637   1728.907874      52.795295
# 1       77.593258       1596.919637   1728.907874      52.795295
# 2       77.593258       1596.919637   1728.907874      52.795295
# 3       77.593258       1596.919637   1728.907874      52.795295
# 4       77.593258       1596.919637   1728.907874      52.795295
#
#    endglicko2sigma
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 28 columns]

# %%
pool = df.groupby(['start', 'team']).first()[['prize', 'tour']].groupby('tour').sum().reset_index().rename(columns={'prize': 'pool'})
pool.head()
# Out:
#                                    tour      pool
# 0            2013 WPC ACE Dota 2 League  254534.0
# 1  2015 Red Bull Battle Grounds: Dota 2   88295.0
# 2           AMD Premier League Season 1    6500.0
# 3           AMD Premier League Season 2    7000.0
# 4          AMD SAPPHIRE Dota PIT League  300000.0

# %%
df = pd.merge(df, pool, how='left', on=['tour'])

# %%
df2 = pd.read_csv('dob.csv', encoding = "ISO-8859-1")
df2.head()
# Out:
#           country       player                         name         dob
# 0          Russia         .Ark            Egor Zhabotinskii  1997-07-07
# 1         Denmark  13abyKnight                 Jon Andersen  1992-06-15
# 2          Canada         1437  Sivatheeban Sivanathapillai         NaN
# 3           China          290                    Zeng Chen         NaN
# 4  United Kingdom          2GD                James Harding  1982-12-29

# %%
df2.player = df2.player.replace(r'\W+', '', regex=True).str.lower()
df2.dob = pd.to_datetime(df2.dob)
print(df2.dtypes)
df2.head()
# Out:
# country            object
# player             object
# name               object
# dob        datetime64[ns]
# dtype: object
#           country       player                         name        dob
# 0          Russia          ark            Egor Zhabotinskii 1997-07-07
# 1         Denmark  13abyknight                 Jon Andersen 1992-06-15
# 2          Canada         1437  Sivatheeban Sivanathapillai        NaT
# 3           China          290                    Zeng Chen        NaT
# 4  United Kingdom          2gd                James Harding 1982-12-29

# %%
df = pd.merge(df, df2, how='left', on=['player'])

# %%
ra = df[['team', 'player', 'dob', 'position', 'tour', 'place', 'prize', 'pool', 'start', 'end', 'startelo64', 'endelo64']]
print(len(ra))
print(len(ra.dropna()))
ra = ra.dropna().sort_values('start').reset_index().drop('index', axis=1)
# Out:
# 9240
# 4717

# %%
ra = ra.rename(columns={'startelo64': 'srt', 'endelo64': 'ert'})
ra.head()
# Out:
#                    team      player        dob  position  \
# 0           Mousesports      kuroky 1992-10-28         5
# 1           Mousesports  sexybamboe 1992-01-20         3
# 2  Counter Logic Gaming     pajkatt 1992-09-19         1
# 3  Counter Logic Gaming      misery 1991-07-14         2
# 4  Counter Logic Gaming     lacoste 1987-11-22         3
#
#                      tour  place    prize       pool      start        end  \
# 0  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 1  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 2  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 3  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 4  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
#
#            srt         ert
# 0  1054.248131  854.326942
# 1  1054.248131  854.326942
# 2  1269.147739  957.474795
# 3  1269.147739  957.474795
# 4  1269.147739  957.474795

# %%
ra['age'] = (ra.start - ra.dob).dt.days

# %%
for player in ra.player.unique():
    try:
        dfid = pd.DataFrame(ra[ra['player'] == player].tour.unique()).reset_index().rename(columns={'index': 'exp', 0: 'tour'})
        dfid['player'] = player
        dfid2 = pd.concat([dfid2, dfid])
    except NameError:
        dfid2 = dfid
        continue

# %%
ra = pd.merge(ra, dfid2, how='left', on=['player', 'tour'])

# %%
ra.head()
# Out:
#                    team      player        dob  position  \
# 0           Mousesports      kuroky 1992-10-28         5
# 1           Mousesports  sexybamboe 1992-01-20         3
# 2  Counter Logic Gaming     pajkatt 1992-09-19         1
# 3  Counter Logic Gaming      misery 1991-07-14         2
# 4  Counter Logic Gaming     lacoste 1987-11-22         3
#
#                      tour  place    prize       pool      start        end  \
# 0  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 1  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 2  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 3  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 4  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
#
#            srt         ert   age  exp
# 0  1054.248131  854.326942  7242    0
# 1  1054.248131  854.326942  7524    0
# 2  1269.147739  957.474795  7281    0
# 3  1269.147739  957.474795  7714    0
# 4  1269.147739  957.474795  9044    0

# %%
ti = ra[ra['tour'].str[:17] == 'The International'].groupby('tour').first()[['pool', 'start', 'end']]
ti
# Out:
#                               pool      start        end
# tour
# The International 2012   1775000.0 2012-08-26 2012-09-02
# The International 2013   3219309.0 2013-08-02 2013-08-11
# The International 2014  10967674.0 2014-07-08 2014-07-21
# The International 2015  17600281.0 2015-07-27 2015-08-08
# The International 2016  13916298.0 2016-08-02 2016-08-13
# The International 2017  24687919.0 2017-08-02 2017-08-12

# %%
ra['weight'] = ra['pool']
for i in range(0, 5):
    ra.loc[(ra['start'] >= ti['start'].iloc[i]) & (ra['start'] <= ti['start'].iloc[i+1]), 'weight'] = ra[(ra['start'] >= ti['start'].iloc[i]) & (ra['start'] <= ti['start'].iloc[i+1])]['pool'].apply(np.log) / np.log(ti['pool'].iloc[i])

#Only before ti7
ra = ra[ra['start'] < ti['start'].iloc[5]]

# %%
init = ra.sort_values('start').groupby('player').first()['srt'].reset_index().rename(columns={'srt': 'init'})
init.head()
# Out:
#      player         init
# 0            1006.800604
# 1        33  1013.682296
# 2       4dr   924.234998
# 3  7ckngmad  1022.550958
# 4    9pasha  1315.094989

# %%
ra = pd.merge(ra, init, how='left', on=['player'])

# %%
ra['drt'] = ra.ert - ra.srt
ra.head()
# Out:
#                    team      player        dob  position  \
# 0           Mousesports      kuroky 1992-10-28         5
# 1           Mousesports  sexybamboe 1992-01-20         3
# 2  Counter Logic Gaming     pajkatt 1992-09-19         1
# 3  Counter Logic Gaming      misery 1991-07-14         2
# 4  Counter Logic Gaming     lacoste 1987-11-22         3
#
#                      tour  place    prize       pool      start        end  \
# 0  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 1  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 2  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 3  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
# 4  The International 2012      7  25000.0  1775000.0 2012-08-26 2012-09-02
#
#            srt         ert   age  exp  weight         init         drt
# 0  1054.248131  854.326942  7242    0     1.0  1054.248131 -199.921189
# 1  1054.248131  854.326942  7524    0     1.0  1054.248131 -199.921189
# 2  1269.147739  957.474795  7281    0     1.0  1269.147739 -311.672944
# 3  1269.147739  957.474795  7714    0     1.0  1269.147739 -311.672944
# 4  1269.147739  957.474795  9044    0     1.0  1269.147739 -311.672944

# %%
cumsums = ra[['player', 'start', 'drt']].groupby(['player', 'start']).sum().groupby(level=0).cumsum()
ra = ra.set_index(['player', 'start'])
ra['cumrt'] = cumsums
ra = ra.reset_index()
ra.head()
# Out:
#        player      start                  team        dob  position  \
# 0      kuroky 2012-08-26           Mousesports 1992-10-28         5
# 1  sexybamboe 2012-08-26           Mousesports 1992-01-20         3
# 2     pajkatt 2012-08-26  Counter Logic Gaming 1992-09-19         1
# 3      misery 2012-08-26  Counter Logic Gaming 1991-07-14         2
# 4     lacoste 2012-08-26  Counter Logic Gaming 1987-11-22         3
#
#                      tour  place    prize       pool        end          srt  \
# 0  The International 2012      7  25000.0  1775000.0 2012-09-02  1054.248131
# 1  The International 2012      7  25000.0  1775000.0 2012-09-02  1054.248131
# 2  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
# 3  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
# 4  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
#
#           ert   age  exp  weight         init         drt       cumrt
# 0  854.326942  7242    0     1.0  1054.248131 -199.921189 -199.921189
# 1  854.326942  7524    0     1.0  1054.248131 -199.921189 -199.921189
# 2  957.474795  7281    0     1.0  1269.147739 -311.672944 -311.672944
# 3  957.474795  7714    0     1.0  1269.147739 -311.672944 -311.672944
# 4  957.474795  9044    0     1.0  1269.147739 -311.672944 -311.672944

# %%
ra['crt'] = (ra.weight * ra.cumrt) + ra.init
ra.head()
# Out:
#        player      start                  team        dob  position  \
# 0      kuroky 2012-08-26           Mousesports 1992-10-28         5
# 1  sexybamboe 2012-08-26           Mousesports 1992-01-20         3
# 2     pajkatt 2012-08-26  Counter Logic Gaming 1992-09-19         1
# 3      misery 2012-08-26  Counter Logic Gaming 1991-07-14         2
# 4     lacoste 2012-08-26  Counter Logic Gaming 1987-11-22         3
#
#                      tour  place    prize       pool        end          srt  \
# 0  The International 2012      7  25000.0  1775000.0 2012-09-02  1054.248131
# 1  The International 2012      7  25000.0  1775000.0 2012-09-02  1054.248131
# 2  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
# 3  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
# 4  The International 2012      7  25000.0  1775000.0 2012-09-02  1269.147739
#
#           ert   age  exp  weight         init         drt       cumrt  \
# 0  854.326942  7242    0     1.0  1054.248131 -199.921189 -199.921189
# 1  854.326942  7524    0     1.0  1054.248131 -199.921189 -199.921189
# 2  957.474795  7281    0     1.0  1269.147739 -311.672944 -311.672944
# 3  957.474795  7714    0     1.0  1269.147739 -311.672944 -311.672944
# 4  957.474795  9044    0     1.0  1269.147739 -311.672944 -311.672944
#
#           crt
# 0  854.326942
# 1  854.326942
# 2  957.474795
# 3  957.474795
# 4  957.474795

# %%
ra = ra.drop(['srt', 'ert', 'init', 'drt', 'cumrt'], axis=1)
ra.tail()
# Out:
#           player      start           team        dob  position  \
# 4245      kuroky 2017-07-21    Team Liquid 1992-10-28         5
# 4246  alohadance 2017-07-21  Vega Squadron 1997-09-15         1
# 4247           g 2017-07-21  Vega Squadron 1992-04-16         2
# 4248   afterlife 2017-07-21  Vega Squadron 1997-03-13         3
# 4249  matumbaman 2017-07-21    Team Liquid 1995-03-03         1
#
#                       tour  place    prize      pool        end   age  exp  \
# 4245  DreamLeague Season 7      1  80000.0  175000.0 2017-07-22  9032   59
# 4246  DreamLeague Season 7      4  20000.0  175000.0 2017-07-22  7249   23
# 4247  DreamLeague Season 7      4  20000.0  175000.0 2017-07-22  9227   19
# 4248  DreamLeague Season 7      4  20000.0  175000.0 2017-07-22  7435   11
# 4249  DreamLeague Season 7      1  80000.0  175000.0 2017-07-22  8176   19
#
#         weight          crt
# 4245  0.733957  1258.398246
# 4246  0.733957  1281.273997
# 4247  0.733957  1098.113645
# 4248  0.733957  1084.259969
# 4249  0.733957  1452.481802

# %%
ra[['player', 'team', 'crt', 'end']].groupby('player').max().sort_values('crt', ascending=False)
# Out:
#                                 team          crt        end
# player
# ppd                    Team Dignitas  2628.106510 2016-08-13
# n0tail                            OG  2523.574588 2017-07-09
# ddc                      Vici Gaming  2517.175656 2017-07-09
# era                Ninjas in Pyjamas  2446.383096 2017-07-09
# yao                LGD.Forever Young  2426.861980 2017-07-09
# eternalenvy              Team Secret  2400.559545 2017-06-18
# fly                               OG  2400.124832 2017-07-09
# trixi                      Fnatic.EU  2356.070851 2016-11-26
# faith                         TongFu  2233.806940 2017-07-09
# xiao8                         Newbee  2221.095411 2016-12-26
# sumail                 Evil Geniuses  2094.991048 2017-05-28
# lanm                         Team DK  2063.337826 2016-12-31
# yyf                  Invictus Gaming  2048.353455 2014-07-21
# zai                      Team Secret  2034.205924 2017-07-09
# bone7                 Prodota Gaming  1994.303448 2016-12-16
# universe                 Team Secret  1982.612806 2017-07-09
# arteezy                  Team Secret  1963.498132 2017-07-09
# chuan                    Vici Gaming  1950.262648 2017-06-18
# hao                      Vici Gaming  1942.671080 2017-06-18
# yoky                      Virtus.pro  1941.762102 2016-06-19
# burning                  Vici Gaming  1913.962339 2017-07-09
# luo                  Invictus Gaming  1912.407535 2016-07-17
# miracle                  Team Liquid  1872.675224 2017-07-22
# mmy                          Team DK  1808.694736 2016-09-25
# mason                  Evil Geniuses  1719.154235 2017-06-18
# sylar                    Vici Gaming  1703.532284 2016-12-31
# lightofheaven             Virtus.pro  1685.105677 2014-01-19
# oldchicken                     EHOME  1631.613040 2016-12-31
# eleven                    LGD Gaming  1631.613040 2017-07-09
# xboct                     Virtus.pro  1619.642573 2016-03-20
# ...                              ...          ...        ...
# ahfu            WarriorsGaming.Unity   989.204148 2017-07-09
# jenkins               Team Leviathan   986.465929 2016-02-08
# sunlight                 Team Empire   986.222407 2013-07-26
# waixi                    Brave Heart   980.015054 2016-12-26
# bimbo                     Execration   978.102087 2014-10-26
# rr                        Execration   978.102087 2014-10-26
# kotarhayama             Team Unknown   962.534887 2015-11-21
# accel                   Team Unknown   962.534887 2017-07-09
# ztok                    Team Unknown   962.534887 2015-11-21
# moo                      Team Archon   961.364548 2017-05-31
# lacoste         Counter Logic Gaming   957.474795 2012-09-02
# mirakel         Counter Logic Gaming   957.474795 2012-09-02
# mitch                    Team Empire   947.076765 2013-07-24
# afoninje                      Effect   938.829549 2017-05-18
# rodjer                   Team Empire   938.829549 2017-06-18
# c4t                      SG e-sports   936.100954 2017-07-09
# 4dr                      SG e-sports   936.100954 2017-07-09
# tavo                     SG e-sports   936.100954 2017-07-09
# keyser                Prodota Gaming   928.587761 2017-05-18
# milan                 Prodota Gaming   928.587761 2017-05-18
# noia                    Danish Bears   926.465466 2017-06-03
# hestejoerotten          Danish Bears   926.465466 2017-06-03
# ace                      Mousesports   926.220421 2017-06-03
# realaxxx           Basically Unknown   920.637006 2015-06-15
# winter                Orange Esports   912.466315 2014-11-02
# kabu                          TongFu   885.604461 2016-09-25
# sexybamboe            Prodota Gaming   854.326942 2016-12-16
# godot                 Can't Say Wips   837.673833 2015-03-22
# tudi                  Can't Say Wips   837.673833 2015-03-22
# nana            WarriorsGaming.Unity   818.901431 2017-06-03
#
# [270 rows x 3 columns]

# %%
ra[ra['player'] == 'ppd'][['start', 'crt']].set_index('start').plot()

# %%
ra.head()
# Out:
#        player      start                  team        dob  position  \
# 0      kuroky 2012-08-26           Mousesports 1992-10-28         5
# 1  sexybamboe 2012-08-26           Mousesports 1992-01-20         3
# 2     pajkatt 2012-08-26  Counter Logic Gaming 1992-09-19         1
# 3      misery 2012-08-26  Counter Logic Gaming 1991-07-14         2
# 4     lacoste 2012-08-26  Counter Logic Gaming 1987-11-22         3
#
#                      tour  place    prize       pool        end   age  exp  \
# 0  The International 2012      7  25000.0  1775000.0 2012-09-02  7242    0
# 1  The International 2012      7  25000.0  1775000.0 2012-09-02  7524    0
# 2  The International 2012      7  25000.0  1775000.0 2012-09-02  7281    0
# 3  The International 2012      7  25000.0  1775000.0 2012-09-02  7714    0
# 4  The International 2012      7  25000.0  1775000.0 2012-09-02  9044    0
#
#    weight         crt
# 0     1.0  854.326942
# 1     1.0  854.326942
# 2     1.0  957.474795
# 3     1.0  957.474795
# 4     1.0  957.474795

# %%
ra.to_csv('tostata2.csv', index=False)

# %%
ra.reset_index().head()
# Out:
#               player            team        dob  position  \
# id start
# 0  2016-12-14     33  Prodota Gaming 1997-04-17         2
#    2017-05-02     33  Prodota Gaming 1997-04-17         3
# 1  2015-11-28    4dr     PaiN Gaming 1993-07-13         1
#    2017-04-24    4dr     SG e-sports 1993-07-13         2
#    2017-05-30    4dr     SG e-sports 1993-07-13         2
#
#                                            tour  place     prize       pool  \
# id start
# 0  2016-12-14            World Cyber Arena 2016      4   28744.0   732972.0
#    2017-05-02       Mr. Cat Invitational Europe      4    5000.0    70000.0
# 1  2015-11-28        Dota 2 Canada Cup Season 6      3    4076.0    93751.0
#    2017-04-24               The Kiev Major 2017      5  125000.0  3000000.0
#    2017-05-30  DreamLeague Season 7 NA Division      4    1000.0    12000.0
#
#                      end   age  exp    weight          crt      age2  \
# id start
# 0  2016-12-14 2016-12-16  7181    0  0.821036   999.974471  51566761
#    2017-05-02 2017-05-18  7320    1  0.678250  1026.367702  53582400
# 1  2015-11-28 2016-02-08  8173    0  0.686214   900.438705  66797929
#    2017-04-24 2017-04-30  8686    1  0.906712   936.100954  75446596
#    2017-05-30 2017-05-31  8722    2  0.571032   931.489252  76073284
#
#                        age3  exp2  exp3  const
# id start
# 0  2016-12-14  370300910741     0     0      1
#    2017-05-02  392223168000     1     1      1
# 1  2015-11-28  545939473717     0     0      1
#    2017-04-24  655329132856     1     1      1
#    2017-05-30  663511183048     4     8      1

# %%
len(ra)
# Out:
# 3968

# %%
len(ra.reset_index().drop_duplicates(subset=['start', 'player']))
# Out:
# 3932

# %%
ra = ra.reset_index().drop_duplicates(subset=['start', 'player'])

# %%
ra = ra[ra['player'] != '']
ra = ra[(ra['age'] > 6570) & (ra['age'] < 10220)]

# %%
ra = pd.merge(ra, ra.groupby('player').size().reset_index().reset_index().drop(0,axis=1).rename(columns={'index': 'id'}), how='left', on=['player'])

# %%
#analysis
ra = ra.set_index(['id', 'start']).sort_index()
ra['age2'] = ra.age ** 2
ra['age3'] = ra.age ** 3
ra['exp2'] = ra.exp ** 2
ra['exp3'] = ra.exp ** 3

# %%
y = ra['crt']
x = ra['exp']
plt.scatter(x, y)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 2))(np.unique(x)), 'r')

# %%
ra['const'] = 1

# %%
y = ra['crt']
x = ra[['age', 'age2', 'exp', 'exp2', 'const']]
mod = sm.OLS(y, x)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    crt   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     9.992
# Date:                Fri, 26 Jan 2018   Prob (F-statistic):           4.81e-08
# Time:                        15:09:02   Log-Likelihood:                -29369.
# No. Observations:                3968   AIC:                         5.875e+04
# Df Residuals:                    3963   BIC:                         5.878e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            0.0755      0.138      0.548      0.584      -0.195       0.346
# age2       -5.572e-06   8.26e-06     -0.675      0.500   -2.18e-05    1.06e-05
# exp            8.1580      1.385      5.892      0.000       5.443      10.873
# exp2          -0.1338      0.028     -4.696      0.000      -0.190      -0.078
# const        873.1264    571.360      1.528      0.127    -247.061    1993.314
# ==============================================================================
# Omnibus:                       99.771   Durbin-Watson:                   0.131
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              233.974
# Skew:                           0.038   Prob(JB):                     1.56e-51
# Kurtosis:                       4.187   Cond. No.                     6.50e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.5e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
cor['lexp'] = np.add(cor.exp, 1).apply(np.log)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-4061300ed950> in <module>()
# ----> 1 cor['lexp'] = np.add(cor.exp, 1).apply(np.log)
#
# NameError: name 'cor' is not defined

# %%
cor.head()

# %%
#core vs sup
cor = ra[ra['position'] <= 3]
sup = ra[ra['position'] > 3]

# %%
y = cor['crt']
x = cor[['age', 'age2', 'lexp', 'const']]
mod = sm.OLS(y, x)
res = mod.fit()
res.summary()

# %%
y = cor['crt']
x = cor[['age', 'age2', 'age3', 'exp', 'exp2', 'const']]
mod = sm.OLS(y, x)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    crt   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     22.15
# Date:                Fri, 26 Jan 2018   Prob (F-statistic):           9.68e-22
# Time:                        16:00:45   Log-Likelihood:                -17063.
# No. Observations:                2313   AIC:                         3.414e+04
# Df Residuals:                    2307   BIC:                         3.417e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age          -15.5484      2.334     -6.662      0.000     -20.125     -10.971
# age2           0.0018      0.000      6.486      0.000       0.001       0.002
# age3       -7.122e-08   1.13e-08     -6.299      0.000   -9.34e-08   -4.91e-08
# exp            9.1279      1.848      4.938      0.000       5.503      12.753
# exp2          -0.2466      0.040     -6.203      0.000      -0.325      -0.169
# const       4.479e+04   6399.098      7.000      0.000    3.22e+04    5.73e+04
# ==============================================================================
# Omnibus:                       67.743   Durbin-Watson:                   0.170
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.249
# Skew:                          -0.033   Prob(JB):                     1.77e-37
# Kurtosis:                       4.324   Cond. No.                     4.83e+14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.83e+14. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sup['lexp'] = np.add(sup.exp, 1).apply(np.log)

# %%
y = sup['crt']
x = sup[['age', 'age2', 'lexp', 'const']]
mod = sm.OLS(y, x)
res = mod.fit()
res.summary()

# %%
len(cor)

# %%
ra = ra.set_index(['id', 'start'])

# %%
cor.head()
# Out:
#               player            team        dob  position  \
# id start
# 0  2016-12-14     33  Prodota Gaming 1997-04-17         2
#    2017-05-02     33  Prodota Gaming 1997-04-17         3
# 1  2015-11-28    4dr     PaiN Gaming 1993-07-13         1
#    2017-04-24    4dr     SG e-sports 1993-07-13         2
#    2017-05-30    4dr     SG e-sports 1993-07-13         2
#
#                                            tour  place     prize       pool  \
# id start
# 0  2016-12-14            World Cyber Arena 2016      4   28744.0   732972.0
#    2017-05-02       Mr. Cat Invitational Europe      4    5000.0    70000.0
# 1  2015-11-28        Dota 2 Canada Cup Season 6      3    4076.0    93751.0
#    2017-04-24               The Kiev Major 2017      5  125000.0  3000000.0
#    2017-05-30  DreamLeague Season 7 NA Division      4    1000.0    12000.0
#
#                      end   age  exp    weight          crt      age2  \
# id start
# 0  2016-12-14 2016-12-16  7181    0  0.821036   999.974471  51566761
#    2017-05-02 2017-05-18  7320    1  0.678250  1026.367702  53582400
# 1  2015-11-28 2016-02-08  8173    0  0.686214   900.438705  66797929
#    2017-04-24 2017-04-30  8686    1  0.906712   936.100954  75446596
#    2017-05-30 2017-05-31  8722    2  0.571032   931.489252  76073284
#
#                        age3  exp2  exp3  const
# id start
# 0  2016-12-14  370300910741     0     0      1
#    2017-05-02  392223168000     1     1      1
# 1  2015-11-28  545939473717     0     0      1
#    2017-04-24  655329132856     1     1      1
#    2017-05-30  663511183048     4     8      1

# %%
#CORE
y1 = cor['crt']
x1 = cor[['age', 'age2', 'age3']]
mod = PanelOLS(y1, x1, entity_effects=True)
res = mod.fit(cov_type='clustered', cluster_entity=True)
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    crt   R-squared:                        0.0182
# Estimator:                   PanelOLS   R-squared (Between):             -0.1390
# No. Observations:                2313   R-squared (Within):               0.0182
# Date:                Fri, Jan 26 2018   R-squared (Overall):             -0.0234
# Time:                        16:02:36   Log-likelihood                -1.556e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      19.628
# Entities:                         254   P-value                           0.0000
# Avg Obs:                       9.1063   Distribution:                  F(2,2122)
# Min Obs:                       0.0000
# Max Obs:                       60.000   F-statistic (robust):             37.526
#                                         P-value                           0.0000
# Time periods:                     183   Distribution:                  F(2,2122)
# Avg Obs:                       12.639
# Min Obs:                       1.0000
# Max Obs:                       40.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            0.7475     0.4942     1.5127     0.1305     -0.2215      1.7166
# age2          -0.0001     0.0001    -0.9797     0.3273     -0.0004      0.0001
# age3        5.494e-09  7.397e-09     0.7428     0.4577  -9.011e-09       2e-08
# ==============================================================================
#
# F-test for Poolability: 31.789
# P-value: 0.0000
# Distribution: F(188,2122)
#
# Included effects: Entity
# """

# %%
#CORE
y1 = ra['crt']
x1 = ra[['age', 'age2', 'age3']]
mod = PanelOLS(y1, x1, entity_effects=True)
res = mod.fit(cov_type='clustered', cluster_entity=True)
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    crt   R-squared:                        0.0007
# Estimator:                   PanelOLS   R-squared (Between):             -0.0631
# No. Observations:                3932   R-squared (Within):               0.0007
# Date:                Fri, Jan 26 2018   R-squared (Overall):             -0.0030
# Time:                        16:03:04   Log-likelihood                -2.646e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.3145
# Entities:                         255   P-value                           0.2687
# Avg Obs:                       15.420   Distribution:                  F(2,3675)
# Min Obs:                       1.0000
# Max Obs:                       68.000   F-statistic (robust):             45.501
#                                         P-value                           0.0000
# Time periods:                     183   Distribution:                  F(2,3675)
# Avg Obs:                       21.486
# Min Obs:                       1.0000
# Max Obs:                       67.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            0.5118     0.3311     1.5458     0.1222     -0.1373      1.1610
# age2       -6.883e-05  7.942e-05    -0.8666     0.3862     -0.0002   8.689e-05
# age3        2.924e-09  4.741e-09     0.6167     0.5374  -6.372e-09   1.222e-08
# ==============================================================================
#
# F-test for Poolability: 41.757
# P-value: 0.0000
# Distribution: F(254,3675)
#
# Included effects: Entity
# """

# %%
cor.head()
# Out:
#               player            team        dob  position  \
# id start
# 0  2016-12-14     33  Prodota Gaming 1997-04-17         2
#    2017-05-02     33  Prodota Gaming 1997-04-17         3
# 1  2015-11-28    4dr     PaiN Gaming 1993-07-13         1
#    2017-04-24    4dr     SG e-sports 1993-07-13         2
#    2017-05-30    4dr     SG e-sports 1993-07-13         2
#
#                                            tour  place     prize       pool  \
# id start
# 0  2016-12-14            World Cyber Arena 2016      4   28744.0   732972.0
#    2017-05-02       Mr. Cat Invitational Europe      4    5000.0    70000.0
# 1  2015-11-28        Dota 2 Canada Cup Season 6      3    4076.0    93751.0
#    2017-04-24               The Kiev Major 2017      5  125000.0  3000000.0
#    2017-05-30  DreamLeague Season 7 NA Division      4    1000.0    12000.0
#
#                      end   age  exp    weight          crt      age2  \
# id start
# 0  2016-12-14 2016-12-16  7181    0  0.821036   999.974471  51566761
#    2017-05-02 2017-05-18  7320    1  0.678250  1026.367702  53582400
# 1  2015-11-28 2016-02-08  8173    0  0.686214   900.438705  66797929
#    2017-04-24 2017-04-30  8686    1  0.906712   936.100954  75446596
#    2017-05-30 2017-05-31  8722    2  0.571032   931.489252  76073284
#
#                        age3  exp2  exp3  const
# id start
# 0  2016-12-14  370300910741     0     0      1
#    2017-05-02  392223168000     1     1      1
# 1  2015-11-28  545939473717     0     0      1
#    2017-04-24  655329132856     1     1      1
#    2017-05-30  663511183048     4     8      1

# %%
cor.reset_index().to_csv('corestata.csv', index=False)
sup.reset_index().to_csv('supstata.csv', index=False)
